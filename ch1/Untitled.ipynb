# %%
Post
# Out:
# blog.models.Post

# %%
Post.object.all()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-9d1da07d3c7e> in <module>()
# ----> 1 Post.object.all()
#
# AttributeError: type object 'Post' has no attribute 'object'

# %%
Post.objects.all()
# Out:
# <QuerySet [<Post: 자바스크립트>, <Post: 김진아>, <Post: 와 이젠 편히 잘수 있겠다.>, <Post: 음 기능 거의다 포함>, <Post: fadasdfaf>, <Post: 공부란>, <Post: naver>, <Post: jquery>, <Post: dfaf>, <Post: naver>, <Post: 파이썬 이즈 베리 딜리셔스>, <Post: naver>]>

# %%
Post.objects.all(id=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-2c84861702a2> in <module>()
# ----> 1 Post.objects.all(id=1)
#
# TypeError: all() got an unexpected keyword argument 'id'

# %%
Post.objects.all(title='자바스크립트')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-a8c283bc9fdc> in <module>()
# ----> 1 Post.objects.all(title='자바스크립트')
#
# TypeError: all() got an unexpected keyword argument 'title'

# %%
Category.objects.all()
# Out:
# <QuerySet [<Category: Python>, <Category: Javascript>, <Category: Django>, <Category: iOS>, <Category: Android>, <Category: jQuery>, <Category: HTML/CSS>, <Category: Java>, <Category: C/C++>, <Category: Arduino/Raspberry Pi>, <Category: 정보처리 기능사>, <Category: Design>, <Category: Algorithm>, <Category: TIL>]>

# %%
Category.objects.all()
# Out:
# <QuerySet [<Category: Python>, <Category: Javascript>, <Category: Django>, <Category: iOS>, <Category: Android>, <Category: jQuery>, <Category: HTML/CSS>, <Category: Java>, <Category: C/C++>, <Category: Arduino/Raspberry Pi>, <Category: 정보처리 기능사>, <Category: Design>, <Category: Algorithm>, <Category: TIL>]>

# %%
a=Category.obejects.get(name="Python")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-2cb96a3c1945> in <module>()
# ----> 1 a=Category.obejects.get(name="Python")
#
# AttributeError: type object 'Category' has no attribute 'obejects'

# %%
a = Category.objects.get(name="Python")

# %%
post = Post.objects.all()

# %%
post.category_id
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-b820c8835f85> in <module>()
# ----> 1 post.category_id
#
# AttributeError: 'QuerySet' object has no attribute 'category_id'

# %%
cagegory = Category.objects.all()

# %%
post = post.filter(cagegory.name="Python")
# Out:
#   File "<ipython-input-16-ee2ff8eceaca>", line 1
#     post = post.filter(cagegory.name="Python")
#                       ^
# SyntaxError: keyword can't be an expression

# %%
cagegory.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-d2e88deb3e81> in <module>()
# ----> 1 cagegory.name
#
# AttributeError: 'QuerySet' object has no attribute 'name'

# %%
cagegory
# Out:
# <QuerySet [<Category: Python>, <Category: Javascript>, <Category: Django>, <Category: iOS>, <Category: Android>, <Category: jQuery>, <Category: HTML/CSS>, <Category: Java>, <Category: C/C++>, <Category: Arduino/Raspberry Pi>, <Category: 정보처리 기능사>, <Category: Design>, <Category: Algorithm>, <Category: TIL>]>

# %%
cagegory.title
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-ac3a5e529720> in <module>()
# ----> 1 cagegory.title
#
# AttributeError: 'QuerySet' object has no attribute 'title'

# %%
cagegory.id
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-e842a5b3a99e> in <module>()
# ----> 1 cagegory.id
#
# AttributeError: 'QuerySet' object has no attribute 'id'

# %%
post.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-5d2efb52a041> in <module>()
# ----> 1 post.name
#
# AttributeError: 'QuerySet' object has no attribute 'name'

# %%
post
# Out:
# <QuerySet [<Post: 자바스크립트>, <Post: 김진아>, <Post: 와 이젠 편히 잘수 있겠다.>, <Post: 음 기능 거의다 포함>, <Post: fadasdfaf>, <Post: 공부란>, <Post: naver>, <Post: jquery>, <Post: dfaf>, <Post: naver>, <Post: 파이썬 이즈 베리 딜리셔스>, <Post: naver>]>

# %%
Post.objects.filter(category__name="Python")
# Out:
# <QuerySet [<Post: 음 기능 거의다 포함>, <Post: dfaf>, <Post: naver>, <Post: 파이썬 이즈 베리 딜리셔스>, <Post: naver>]>
